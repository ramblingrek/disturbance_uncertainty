# %%
# Master notebook for disturbance uncertainty stuff


# Workflow
'''
1. First, generate global samples using 02_generate_global_samples.ipynb


# Key notebooks: 
01_dev_create_disturbance_landscape_code_november2025_v2.ipynb

This one is where I worked on developing the core code to create the landscape, the sensor field, and the interpreter field. We don't actually need to run this any more -- it's just for reference in the evolution.  In theory, I can use the 03_landscape.... one to build landscapes. 

02_generate_global_samples.ipynb

This is the one to build a robust sample of SNIC landscapes in GEE. It puts them in the downloaded_images folder.  I guess we could tweak that for different kinds of experiments. 


03_landscape_stack_builder.ipynb 

This is one where I put together a landsacpe and its sensor and interpreter fields.  Just one landscape

Anticipated: 

A landscape_group object -- this is a container that 

04_build_model_classifier.ipynb

The idea here will be to assemble a set of landscapes, sample from them, and build a classifier from them.  I think that eventually the code will all be wrapped into an experiment class. 

05_apply_model.ipynb

Test applying the model to new landscapes.  
-> Build a new group
