# %%
#. Testing the new approach to doing a run, where set up the json file, and then
#  run things within a notebook and the ouptuts gets stored separately. 

# Path setup
import sys, os, json, copy
sys.path.insert(0, os.path.abspath('../src'))
PROJ_ROOT = os.path.abspath('..')   # notebooks/ → project root

# %%
import sys
sys.path.insert(0, '..')
from experiment_runner import run_experiment

# import os
# print(os.getcwd())

run_id = run_experiment('experiments/configs/baseline.json')
# Out:
# ────────────────────────────────────────────────────────────
#   Loading config: experiments/configs/baseline.json
# ────────────────────────────────────────────────────────────
# run_id      : run_ID_20260515_125836_7607aa
# output root : experiment_outputs/baseline_run_ID_20260515_125836_7607aa
#
# ────────────────────────────────────────────────────────────
#   Building training collection
# ────────────────────────────────────────────────────────────
# Warning: no disturbed pixels generated after max_retries attempts.
#   10 training stacks built
#
# ────────────────────────────────────────────────────────────
#   Fitting continuous model (Richards)
# ────────────────────────────────────────────────────────────
#   Saved model fit figure → experiment_outputs/baseline_run_ID_20260515_125836_7607aa/figures/
#
# ────────────────────────────────────────────────────────────
#   Fitting binary classifier
# ────────────────────────────────────────────────────────────
#   threshold = 667.8687
#   Saved threshold curves figure → experiment_outputs/baseline_run_ID_20260515_125836_7607aa/figures/
#
# ────────────────────────────────────────────────────────────
#   Building validation collection
# ────────────────────────────────────────────────────────────
# Warning: no disturbed pixels generated after max_retries attempts.
#   10 validation stacks built
#
# ────────────────────────────────────────────────────────────
#   Applying models to validation collection
# ────────────────────────────────────────────────────────────
#   Continuous model applied
# Sample size: 4144
# Fitted interpreter-probability model for sensor 'Optical Sensor 1': x0=0.000, b=3.716, nu=3.914
#   Interpreter probability model applied
#   Binary classifier applied
#
# ────────────────────────────────────────────────────────────
#   Evaluating validation collection
# ────────────────────────────────────────────────────────────
#
#   Continuous — median abs error : 0.0000
#   Continuous — mean abs error   : 0.0016
#   Binary     — median abs error : 0.0029
#   Binary     — mean abs error   : 0.0039
#   Saved summary figures + CSVs → experiment_outputs/baseline_run_ID_20260515_125836_7607aa/
#
# ────────────────────────────────────────────────────────────
#   Saving per-stack figures (10 stacks)
# ────────────────────────────────────────────────────────────
# 10th, 50th, and 90th percentile DISTURBED PROPORTIONS: 0.000000, 0.014075, 0.015961
# True disturbed proportion: 0.015462
# ================ AREA PROPORTION SUMMARY (Probability-based) ================
# Stack: 0 (DL_46be2871)   Sensor: Optical Sensor 1   Source: interpreter_calibrated_prob_by_sensor
# Total pixels: 54,069   pixel_area: 900.0   total_area: 48,662,100.000
#
# Estimated disturbed proportion P(class 1) from cutoff-sweep distribution:
#   P5 :  0.000000
#   P50:  0.014075   (median)
#   P95:  1.000000
#
# Estimated undisturbed proportion P(class 0) = 1 - P(class 1):
#   P5 :  0.000000
#   P50:  0.985925   (median)
#   P95:  1.000000
#
# Truth (from base_landscape.disturbed):
#   True disturbed proportion: 0.015462
#   Is truth within [P5, P95] of estimated P(class 1)? True
# 10th, 50th, and 90th percentile DISTURBED PROPORTIONS: 0.000000, 0.012010, 0.015318
# True disturbed proportion: 0.012010
# ================ AREA PROPORTION SUMMARY (Probability-based) ================
# Stack: 1 (DL_8b23c358)   Sensor: Optical Sensor 1   Source: interpreter_calibrated_prob_by_sensor
# Total pixels: 45,046   pixel_area: 900.0   total_area: 40,541,400.000
#
# Estimated disturbed proportion P(class 1) from cutoff-sweep distribution:
#   P5 :  0.000000
#   P50:  0.012010   (median)
#   P95:  1.000000
#
# Estimated undisturbed proportion P(class 0) = 1 - P(class 1):
#   P5 :  0.000000
#   P50:  0.987990   (median)
#   P95:  1.000000
#
# Truth (from base_landscape.disturbed):
#   True disturbed proportion: 0.012010
#   Is truth within [P5, P95] of estimated P(class 1)? True
# 10th, 50th, and 90th percentile DISTURBED PROPORTIONS: 0.000000, 0.034664, 0.035588
# True disturbed proportion: 0.035270
# ================ AREA PROPORTION SUMMARY (Probability-based) ================
# Stack: 2 (DL_bea15018)   Sensor: Optical Sensor 1   Source: interpreter_calibrated_prob_by_sensor
# Total pixels: 97,364   pixel_area: 900.0   total_area: 87,627,600.000
#
# Estimated disturbed proportion P(class 1) from cutoff-sweep distribution:
#   P5 :  0.000000
#   P50:  0.034664   (median)
#   P95:  1.000000
#
# Estimated undisturbed proportion P(class 0) = 1 - P(class 1):
#   P5 :  0.000000
#   P50:  0.965336   (median)
#   P95:  1.000000
#
# Truth (from base_landscape.disturbed):
#   True disturbed proportion: 0.035270
#   Is truth within [P5, P95] of estimated P(class 1)? True
# 10th, 50th, and 90th percentile DISTURBED PROPORTIONS: 0.000000, 0.019724, 0.023438
# True disturbed proportion: 0.015191
# ================ AREA PROPORTION SUMMARY (Probability-based) ================
# Stack: 3 (DL_cf6b674b)   Sensor: Optical Sensor 1   Source: interpreter_calibrated_prob_by_sensor
# Total pixels: 45,225   pixel_area: 900.0   total_area: 40,702,500.000
#
# Estimated disturbed proportion P(class 1) from cutoff-sweep distribution:
#   P5 :  0.000000
#   P50:  0.019724   (median)
#   P95:  1.000000
#
# Estimated undisturbed proportion P(class 0) = 1 - P(class 1):
#   P5 :  0.000000
#   P50:  0.980276   (median)
#   P95:  1.000000
#
# Truth (from base_landscape.disturbed):
#   True disturbed proportion: 0.015191
#   Is truth within [P5, P95] of estimated P(class 1)? True
# 10th, 50th, and 90th percentile DISTURBED PROPORTIONS: 0.000000, 0.017909, 0.027685
# True disturbed proportion: 0.027685
# ================ AREA PROPORTION SUMMARY (Probability-based) ================
# Stack: 4 (DL_c76bd6f7)   Sensor: Optical Sensor 1   Source: interpreter_calibrated_prob_by_sensor
# Total pixels: 48,076   pixel_area: 900.0   total_area: 43,268,400.000
#
# Estimated disturbed proportion P(class 1) from cutoff-sweep distribution:
#   P5 :  0.000000
#   P50:  0.017909   (median)
#   P95:  1.000000
#
# Estimated undisturbed proportion P(class 0) = 1 - P(class 1):
#   P5 :  0.000000
#   P50:  0.982091   (median)
#   P95:  1.000000
#
# Truth (from base_landscape.disturbed):
#   True disturbed proportion: 0.027685
#   Is truth within [P5, P95] of estimated P(class 1)? True
# 10th, 50th, and 90th percentile DISTURBED PROPORTIONS: 0.000000, 0.012567, 0.025960
# True disturbed proportion: 0.012567
# ================ AREA PROPORTION SUMMARY (Probability-based) ================
# Stack: 5 (DL_4b183cb6)   Sensor: Optical Sensor 1   Source: interpreter_calibrated_prob_by_sensor
# Total pixels: 42,411   pixel_area: 900.0   total_area: 38,169,900.000
#
# Estimated disturbed proportion P(class 1) from cutoff-sweep distribution:
#   P5 :  0.000000
#   P50:  0.012567   (median)
#   P95:  1.000000
#
# Estimated undisturbed proportion P(class 0) = 1 - P(class 1):
#   P5 :  0.000000
#   P50:  0.987433   (median)
#   P95:  1.000000
#
# Truth (from base_landscape.disturbed):
#   True disturbed proportion: 0.012567
#   Is truth within [P5, P95] of estimated P(class 1)? True
# 10th, 50th, and 90th percentile DISTURBED PROPORTIONS: 0.000000, 0.020972, 0.027018
# True disturbed proportion: 0.020972
# ================ AREA PROPORTION SUMMARY (Probability-based) ================
# Stack: 6 (DL_ce03e468)   Sensor: Optical Sensor 1   Source: interpreter_calibrated_prob_by_sensor
# Total pixels: 42,009   pixel_area: 900.0   total_area: 37,808,100.000
#
# Estimated disturbed proportion P(class 1) from cutoff-sweep distribution:
#   P5 :  0.000000
#   P50:  0.020972   (median)
#   P95:  1.000000
#
# Estimated undisturbed proportion P(class 0) = 1 - P(class 1):
#   P5 :  0.000000
#   P50:  0.979028   (median)
#   P95:  1.000000
#
# Truth (from base_landscape.disturbed):
#   True disturbed proportion: 0.020972
#   Is truth within [P5, P95] of estimated P(class 1)? True
# 10th, 50th, and 90th percentile DISTURBED PROPORTIONS: 0.000000, 0.000000, 0.000000
# True disturbed proportion: 0.000000
# ================ AREA PROPORTION SUMMARY (Probability-based) ================
# Stack: 7 (DL_89396cf3)   Sensor: Optical Sensor 1   Source: interpreter_calibrated_prob_by_sensor
# Total pixels: 40,401   pixel_area: 900.0   total_area: 36,360,900.000
#
# Estimated disturbed proportion P(class 1) from cutoff-sweep distribution:
#   P5 :  0.000000
#   P50:  0.000000   (median)
#   P95:  1.000000
#
# Estimated undisturbed proportion P(class 0) = 1 - P(class 1):
#   P5 :  0.000000
#   P50:  1.000000   (median)
#   P95:  1.000000
#
# Truth (from base_landscape.disturbed):
#   True disturbed proportion: 0.000000
#   Is truth within [P5, P95] of estimated P(class 1)? True
# 10th, 50th, and 90th percentile DISTURBED PROPORTIONS: 0.000000, 0.038093, 0.042204
# True disturbed proportion: 0.038093
# ================ AREA PROPORTION SUMMARY (Probability-based) ================
# Stack: 8 (DL_5aa5c6ab)   Sensor: Optical Sensor 1   Source: interpreter_calibrated_prob_by_sensor
# Total pixels: 47,436   pixel_area: 900.0   total_area: 42,692,400.000
#
# Estimated disturbed proportion P(class 1) from cutoff-sweep distribution:
#   P5 :  0.000000
#   P50:  0.038093   (median)
#   P95:  1.000000
#
# Estimated undisturbed proportion P(class 0) = 1 - P(class 1):
#   P5 :  0.000000
#   P50:  0.961907   (median)
#   P95:  1.000000
#
# Truth (from base_landscape.disturbed):
#   True disturbed proportion: 0.038093
#   Is truth within [P5, P95] of estimated P(class 1)? True
# 10th, 50th, and 90th percentile DISTURBED PROPORTIONS: 0.000000, 0.028047, 0.039218
# True disturbed proportion: 0.028047
# ================ AREA PROPORTION SUMMARY (Probability-based) ================
# Stack: 9 (DL_4fa4c7a2)   Sensor: Optical Sensor 1   Source: interpreter_calibrated_prob_by_sensor
# Total pixels: 54,873   pixel_area: 900.0   total_area: 49,385,700.000
#
# Estimated disturbed proportion P(class 1) from cutoff-sweep distribution:
#   P5 :  0.000000
#   P50:  0.028047   (median)
#   P95:  1.000000
#
# Estimated undisturbed proportion P(class 0) = 1 - P(class 1):
#   P5 :  0.000000
#   P50:  0.971953   (median)
#   P95:  1.000000
#
# Truth (from base_landscape.disturbed):
#   True disturbed proportion: 0.028047
#   Is truth within [P5, P95] of estimated P(class 1)? True
#   20 files saved → experiment_outputs/baseline_run_ID_20260515_125836_7607aa/figures/per_stack/
#
# ────────────────────────────────────────────────────────────
#   Logging run metadata
# ────────────────────────────────────────────────────────────
#   Logged to experiment_logs/master_experiment_logger.csv
#
# ────────────────────────────────────────────────────────────
#   Complete
# ────────────────────────────────────────────────────────────
#   run_id  : run_ID_20260515_125836_7607aa
#   outputs : experiment_outputs/baseline_run_ID_20260515_125836_7607aa
